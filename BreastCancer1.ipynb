# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import ListedColormap
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("/content/drive/MyDrive/Breast_Cancer.csv")
print(data)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
data.head(10)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
# 5   51  White        Single        T1      N1       IIA
# 6   51  White        Married       T1      N1       IIA
# 7   40  White        Married       T2      N1       IIB
# 8   40  White       Divorced       T4      N3      IIIC
# 9   69  White        Married       T4      N3      IIIC
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# ...

# %%
data.tail(10)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 4014   40  White        Married       T3      N1      IIIA
# 4015   65  White        Married       T2      N2      IIIA
# 4016   54  White        Married       T2      N1       IIB
# 4017   46  White        Married       T2      N1       IIB
# 4018   64  White        Married       T1      N1       IIA
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 4014  Moderately differentiated     2  Regional          68        Positive
# 4015  Moderately differentiated     2  Regional          40        Positive
# 4016        Well differentiated     1  Regional          50        Positive
# ...

# %%
data.shape
# Out:
# (4024, 16)

# %%
data.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   T Stage                 4024 non-null   object
#  4   N Stage                 4024 non-null   object
#  5   6th Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %%
data.isnull()
# Out:
#         Age   Race  Marital Status  T Stage   N Stage  6th Stage  \
# 0     False  False           False     False    False      False
# 1     False  False           False     False    False      False
# 2     False  False           False     False    False      False
# 3     False  False           False     False    False      False
# 4     False  False           False     False    False      False
# ...     ...    ...             ...       ...      ...        ...
# 4019  False  False           False     False    False      False
# 4020  False  False           False     False    False      False
# 4021  False  False           False     False    False      False
# 4022  False  False           False     False    False      False
# 4023  False  False           False     False    False      False
#
#       differentiate  Grade  A Stage  Tumor Size  Estrogen Status  \
# 0             False  False    False       False            False
# ...

# %%
data.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
data['Age'].value_counts()
# Out:
# 46    163
# 49    162
# 47    161
# 53    155
# 55    154
# 63    153
# 62    149
# 51    148
# 59    147
# 50    144
# 57    144
# 61    143
# 60    140
# 48    140
# 56    132
# 54    128
# 65    122
# 58    120
# 67    119
# 66    119
# 52    118
# 64    116
# 68    111
# 69    108
# 45    102
# 43     92
# 42     82
# 44     79
# 40     72
# 41     71
# 39     52
# 38     45
# 37     28
# 36     24
# 35     20
# 33     15
# 31     14
# 34     14
# 32     13
# 30      5
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(25,10))
ax = sns.countplot(data=data, x=data["Age"],palette="Spectral")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title("Value counts of Ages")
plt.xlabel('Age of Breast-Cancer pateints')
# Out:
# Text(0.5, 0, 'Age of Breast-Cancer pateints')

# %%
unique_marital_status = data['Marital Status'].unique()
print("Unique Marital Status Values:", unique_marital_status)

# Cleaning up white spaces and remove any leading/trailing spaces
data['Marital Status'] = data['Marital Status'].str.strip()

# Updating incorrect values, if any
data['Marital Status'].replace({'Single ': 'Single'}, inplace=True)

# Checking unique values again to confirm cleaning
unique_marital_status_cleaned = data['Marital Status'].unique()
print("Unique Marital Status Values (Cleaned):", unique_marital_status_cleaned)

data.to_csv('Breast_Cancer.csv', index=False)
# Out:
# Unique Marital Status Values: ['Married' 'Divorced' 'Single ' 'Widowed' 'Separated']
# Unique Marital Status Values (Cleaned): ['Married' 'Divorced' 'Single' 'Widowed' 'Separated']

# %%
plt.figure(figsize=(6,6))
sns.violinplot(x='Marital Status', y='Survival Months', data=data, palette='Spectral')
plt.title('Violin Plot of Survival Months by Marital Status')
plt.xticks(rotation=45)
plt.show()

# %%
numerical_columns = ['Age', 'Tumor Size', 'Regional Node Examined', 'Reginol Node Positive', 'Survival Months']

numerical_data = data[numerical_columns]

correlation = numerical_data.corr().round(2)
plt.figure(figsize=(14, 7))
sns.heatmap(correlation, annot=True, cmap='RdBu')
plt.title('Correlation Heatmap')
plt.show()

# %%
labels = {
    0: "White Race people",
    1: "Black Race people",
    2: "Other Race"
}

values = {
    0: 3413,
    2: 320,
    1: 291
}

# %%
race_data = pd.DataFrame(values.values(), index=values.keys(), columns=['Count'])

# Ploting the pie chart
colors = ['coral','tan','wheat']  # Use specific colors for each label
explode = (0.1, 0, 0)  # Explode the first slice for emphasis

plt.pie(race_data['Count'], labels=[labels[key] for key in race_data.index], colors=colors, autopct='%1.1f%%', startangle=360, explode=explode)
plt.title("Distribution of Races")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
data['Race'].value_counts()
# Out:
# White    3413
# Other     320
# Black     291
# Name: Race, dtype: int64

# %%
data['T Stage '].value_counts()
# Out:
# T2    1786
# T1    1603
# T3     533
# T4     102
# Name: T Stage , dtype: int64

# %%
data['N Stage'].value_counts()
# Out:
# N1    2732
# N2     820
# N3     472
# Name: N Stage, dtype: int64

# %%
data['Grade'].value_counts()
# Out:
# 2                        2351
# 3                        1111
# 1                         543
#  anaplastic; Grade IV      19
# Name: Grade, dtype: int64

# %%
data['differentiate'].value_counts()
# Out:
# Moderately differentiated    2351
# Poorly differentiated        1111
# Well differentiated           543
# Undifferentiated               19
# Name: differentiate, dtype: int64

# %%
plt.figure(figsize = (20,20))

plt.subplot(3,2,1)
sns.countplot(x = 'Status', hue= 'Race', palette='YlOrBr', data = data)

plt.subplot(3,2,2)
sns.countplot(x = 'Status', hue= 'Marital Status', palette='YlOrBr', data = data)

plt.subplot(3,2,3)
sns.countplot(x = 'Status', hue= 'differentiate', palette='YlOrBr', data = data)

plt.subplot(3,2,4)
sns.countplot(x = 'Status', hue= 'Grade', palette='YlOrBr', data = data)

plt.subplot(3,2,5)
sns.countplot(x = 'Status', hue= 'T Stage ', palette='YlOrBr', data = data)

plt.subplot(3,2,6)
sns.countplot(x = 'Status', hue= 'N Stage', palette='YlOrBr', data = data)
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
data['6th Stage'].value_counts()
# Out:
# IIA     1305
# IIB     1130
# IIIA    1050
# IIIC     472
# IIIB      67
# Name: 6th Stage, dtype: int64

# %%
data['Estrogen Status'].value_counts()
# Out:
# Positive    3755
# Negative     269
# Name: Estrogen Status, dtype: int64

# %%
data['Progesterone Status'].value_counts()
# Out:
# Positive    3326
# Negative     698
# Name: Progesterone Status, dtype: int64

# %%
plt.figure(figsize = (15,10))

plt.subplot(2,2,1)
sns.countplot(x = 'Status', hue= '6th Stage', palette='RdBu', data = data)

plt.subplot(2,2,2)
sns.countplot(x = 'Status', hue= 'Estrogen Status', palette='RdBu', data = data)

plt.subplot(2,2,3)
sns.countplot(x = 'Status', hue= 'Progesterone Status', palette='RdBu', data = data)
# Out:
# <Axes: xlabel='Status', ylabel='count'>

# %%
plt.figure(figsize=(6, 6))
sns.kdeplot(data=data, x='Tumor Size', hue='Status', fill=True, palette='icefire')
plt.title('Tumor Size Distribution by Survival Status')
plt.xlabel('Tumor Size')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.histplot(data=data, x='Age', hue='Status',palette="rocket_r",kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.rcParams['font.size']= 10
sns.pairplot(data,hue='Status', palette='hls')

# %%
a4_dims = (7, 5)
fig, ax = plt.subplots(figsize=a4_dims) # 0 = T1 , 1 = T2 , 2 = T3, 3 = T4
sns.scatterplot(x=data['T Stage '] ,y=data['Tumor Size'],palette='blue').set(xlabel='Tumor Stage', ylabel='Tumor Size')
plt.title("Bar plot of Tumor Stage vs Tumor Size")
plt.show()

# %%
sns.histplot(data["Regional Node Examined"], kde=True, color=("purple"))
plt.title("Regional Node Examined (RNE)")
plt.show()

# %%
k = sns.displot(data['Reginol Node Positive'], kde=True, color=("darkgreen"),height=5,aspect=1,facet_kws=None)
plt.title("Regional Node Positive (RNP)")
plt.show()
